# %%
#Importing required libraries
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
#Mounting drive to preserve the files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Loading the dataset file (.csv from Kaggle)
url = '/content/WineQT.csv'
original_data = pd.read_csv(url)

# %%
#Original data
original_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
#Applying the conditions on the quality feature
original_data['quality'] = original_data['quality'].apply(lambda x: 0 if x <= 6 else 1)
original_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        0   0
# 1      9.8        0   1
# ...

# %%
#Extracting other features and initializing scaler
other_features = data.drop('quality', axis=1)
scaler = MinMaxScaler()

# %%
#Normalizing the features with MinMaxScaler
normalized_features = pd.DataFrame(scaler.fit_transform(other_features), columns=other_features.columns)
normalized_features.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.247788          0.397260         0.00        0.068493   0.106845
# 1       0.283186          0.520548         0.00        0.116438   0.143573
# 2       0.283186          0.438356         0.04        0.095890   0.133556
# 3       0.584071          0.109589         0.56        0.068493   0.105175
# 4       0.247788          0.397260         0.00        0.068493   0.106845
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.149254              0.098940  0.567548  0.606299   0.137725
# 1             0.358209              0.215548  0.494126  0.362205   0.209581
# 2             0.208955              0.169611  0.508811  0.409449   0.191617
# 3             0.238806              0.190813  0.582232  0.330709   0.149701
# 4             0.149254              0.098940  0.567548  0.606299   0.137725
#
#     alcohol        Id
# 0  0.153846  0.000000
# ...

# %%
#Merging both processed datasets
normalized_data = pd.concat([normalized_features, data['quality']], axis=1)
normalized_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.247788          0.397260         0.00        0.068493   0.106845
# 1       0.283186          0.520548         0.00        0.116438   0.143573
# 2       0.283186          0.438356         0.04        0.095890   0.133556
# 3       0.584071          0.109589         0.56        0.068493   0.105175
# 4       0.247788          0.397260         0.00        0.068493   0.106845
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.149254              0.098940  0.567548  0.606299   0.137725
# 1             0.358209              0.215548  0.494126  0.362205   0.209581
# 2             0.208955              0.169611  0.508811  0.409449   0.191617
# 3             0.238806              0.190813  0.582232  0.330709   0.149701
# 4             0.149254              0.098940  0.567548  0.606299   0.137725
#
#     alcohol        Id  quality
# ...

# %%
#Saving the resultant file
normalized_data.to_csv('normalized_wine_data.csv', index=False)
